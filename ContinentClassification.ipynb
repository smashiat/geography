# %% [markdown]
# <a href="https://colab.research.google.com/github/smashiat/geography/blob/main/ContinentClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# get the path/directory
file_path = ["/content/drive/MyDrive/Colab Notebooks/vqalabels/africa_bicycle_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/africa_car_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/africa_truck_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/africa_bus_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/africa_boat_continent.txt"]

output_path = "/content/drive/MyDrive/Colab Notebooks/stats/africa_vqa_continent.txt"
# Ensure the folder exists
target_labels = ["africa", "north america", "europe", "south america", "asia", "australia", "oceania", "antarctica"]
count = 0
current_count = []
captions = []

for fp in file_path:
  with open(fp, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        captions.append(caption)

df = pd.DataFrame(captions, columns=['Captions'])
df = pd.DataFrame({
    'caption': captions
})

for label in target_labels:
    df[f'has_{label}'] = df['caption'].str.contains(label, case=False).astype(int)

af = []
na = []
eu = []
sa = []
asa = []
au = []
oc = []
an = []
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
    indices = np.random.choice(df.index, size=count, replace=True)
    sampled_df = df.loc[indices]
    print(f"sampled", sampled_df, file=output_file)
    column_sums = sampled_df.sum(axis=0)
    print(f"column sums", column_sums, file=output_file)
    column_probs = column_sums[1:9] / count
    print(f"column probs", column_probs, file=output_file)
    af.append(column_probs.iloc[0])
    na.append(column_probs.iloc[1])
    eu.append(column_probs.iloc[2])
    sa.append(column_probs.iloc[3])
    asa.append(column_probs.iloc[4])
    au.append(column_probs.iloc[5])
    oc.append(column_probs.iloc[6])
    an.append(column_probs.iloc[7])

data = {'Category': ['Africa', 'Asia', 'North America', 'Australia', 'South America', 'Europe', 'Antarctica', 'Oceania' ],
        'NumofImages': [count, count, count, count, count, count, count, count], 'Mean': [0, 0, 0, 0, 0, 0, 0, 0], 'Std Dev' : [0, 0, 0, 0, 0, 0, 0, 0] }
de = pd.DataFrame(data)
print(af)
de.loc[de['Category'] == 'Africa', 'Mean'] = np.mean(af)
de.loc[de['Category'] == 'Africa', 'Std Dev'] = np.std(af)
de.loc[de['Category'] == 'Asia', 'Mean'] = np.mean(asa)
de.loc[de['Category'] == 'Asia', 'Std Dev'] = np.std(asa)
de.loc[de['Category'] == 'North America', 'Mean'] = np.mean(na)
de.loc[de['Category'] == 'North America', 'Std Dev'] = np.std(na)
de.loc[de['Category'] == 'Australia', 'Mean'] = np.mean(au)
de.loc[de['Category'] == 'Australia', 'Std Dev'] = np.std(au)
de.loc[de['Category'] == 'South America', 'Mean'] = np.mean(sa)
de.loc[de['Category'] == 'South America', 'Std Dev'] = np.std(sa)
de.loc[de['Category'] == 'Europe', 'Mean'] = np.mean(eu)
de.loc[de['Category'] == 'Europe', 'Std Dev'] = np.std(eu)
de.loc[de['Category'] == 'Antarctica', 'Mean'] = np.mean(an)
de.loc[de['Category'] == 'Antarctica', 'Std Dev'] = np.std(an)
de.loc[de['Category'] == 'Oceania', 'Mean'] = np.mean(oc)
de.loc[de['Category'] == 'Oceania', 'Std Dev'] = np.std(oc)
de.to_csv('/content/drive/My Drive/africa_vqa_continent.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# get the path/directory
file_path = ["/content/drive/MyDrive/Colab Notebooks/vqalabels/southeastasia_bicycle_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/southeastasia_car_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/southeastasia_truck_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/southeastasia_bus_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/southeastasia_boat_continent.txt"]
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/southeastasia_vqa_continent.txt"
# Ensure the folder exists
target_labels = ["africa", "north america", "europe", "south america", "asia", "australia", "oceania", "antarctica"]
count = 0
current_count = []
captions = []

for fp in file_path:
  with open(fp, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        captions.append(caption)

df = pd.DataFrame(captions, columns=['Captions'])
df = pd.DataFrame({
    'caption': captions
})

for label in target_labels:
    df[f'has_{label}'] = df['caption'].str.contains(label, case=False).astype(int)

af = []
na = []
eu = []
sa = []
asa = []
au = []
oc = []
an = []
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
    indices = np.random.choice(df.index, size=count, replace=True)
    sampled_df = df.loc[indices]
    print(f"sampled", sampled_df, file=output_file)
    column_sums = sampled_df.sum(axis=0)
    print(f"column sums", column_sums, file=output_file)
    column_probs = column_sums[1:9] / count
    print(f"column probs", column_probs, file=output_file)
    af.append(column_probs.iloc[0])
    na.append(column_probs.iloc[1])
    eu.append(column_probs.iloc[2])
    sa.append(column_probs.iloc[3])
    asa.append(column_probs.iloc[4])
    au.append(column_probs.iloc[5])
    oc.append(column_probs.iloc[6])
    an.append(column_probs.iloc[7])

data = {'Category': ['Africa', 'Asia', 'North America', 'Australia', 'South America', 'Europe', 'Antarctica', 'Oceania' ],
        'NumofImages': [count, count, count, count, count, count, count, count], 'Mean': [0, 0, 0, 0, 0, 0, 0, 0], 'Std Dev' : [0, 0, 0, 0, 0, 0, 0, 0] }
de = pd.DataFrame(data)
print(af)
de.loc[de['Category'] == 'Africa', 'Mean'] = np.mean(af)
de.loc[de['Category'] == 'Africa', 'Std Dev'] = np.std(af)
de.loc[de['Category'] == 'Asia', 'Mean'] = np.mean(asa)
de.loc[de['Category'] == 'Asia', 'Std Dev'] = np.std(asa)
de.loc[de['Category'] == 'North America', 'Mean'] = np.mean(na)
de.loc[de['Category'] == 'North America', 'Std Dev'] = np.std(na)
de.loc[de['Category'] == 'Australia', 'Mean'] = np.mean(au)
de.loc[de['Category'] == 'Australia', 'Std Dev'] = np.std(au)
de.loc[de['Category'] == 'South America', 'Mean'] = np.mean(sa)
de.loc[de['Category'] == 'South America', 'Std Dev'] = np.std(sa)
de.loc[de['Category'] == 'Europe', 'Mean'] = np.mean(eu)
de.loc[de['Category'] == 'Europe', 'Std Dev'] = np.std(eu)
de.loc[de['Category'] == 'Antarctica', 'Mean'] = np.mean(an)
de.loc[de['Category'] == 'Antarctica', 'Std Dev'] = np.std(an)
de.loc[de['Category'] == 'Oceania', 'Mean'] = np.mean(oc)
de.loc[de['Category'] == 'Oceania', 'Std Dev'] = np.std(oc)
de.to_csv('/content/drive/My Drive/southeastasia_vqa_continent.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# get the path/directory
file_path = ["/content/drive/MyDrive/Colab Notebooks/vqalabels/americas_bicycle_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/americas_car_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/americas_truck_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/americas_bus_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/americas_boat_continent.txt"]
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/americas_vqa_continent.txt"
# Ensure the folder exists
target_labels = ["africa", "north america", "europe", "south america", "asia", "australia", "oceania", "antarctica"]
count = 0
current_count = []
captions = []

for fp in file_path:
  with open(fp, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        captions.append(caption)

df = pd.DataFrame(captions, columns=['Captions'])
df = pd.DataFrame({
    'caption': captions
})

for label in target_labels:
    df[f'has_{label}'] = df['caption'].str.contains(label, case=False).astype(int)

af = []
na = []
eu = []
sa = []
asa = []
au = []
oc = []
an = []
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
    indices = np.random.choice(df.index, size=count, replace=True)
    sampled_df = df.loc[indices]
    print(f"sampled", sampled_df, file=output_file)
    column_sums = sampled_df.sum(axis=0)
    print(f"column sums", column_sums, file=output_file)
    column_probs = column_sums[1:9] / count
    print(f"column probs", column_probs, file=output_file)
    af.append(column_probs.iloc[0])
    na.append(column_probs.iloc[1])
    eu.append(column_probs.iloc[2])
    sa.append(column_probs.iloc[3])
    asa.append(column_probs.iloc[4])
    au.append(column_probs.iloc[5])
    oc.append(column_probs.iloc[6])
    an.append(column_probs.iloc[7])

data = {'Category': ['Africa', 'Asia', 'North America', 'Australia', 'South America', 'Europe', 'Antarctica', 'Oceania' ],
        'NumofImages': [count, count, count, count, count, count, count, count], 'Mean': [0, 0, 0, 0, 0, 0, 0, 0], 'Std Dev' : [0, 0, 0, 0, 0, 0, 0, 0] }
de = pd.DataFrame(data)
print(af)
de.loc[de['Category'] == 'Africa', 'Mean'] = np.mean(af)
de.loc[de['Category'] == 'Africa', 'Std Dev'] = np.std(af)
de.loc[de['Category'] == 'Asia', 'Mean'] = np.mean(asa)
de.loc[de['Category'] == 'Asia', 'Std Dev'] = np.std(asa)
de.loc[de['Category'] == 'North America', 'Mean'] = np.mean(na)
de.loc[de['Category'] == 'North America', 'Std Dev'] = np.std(na)
de.loc[de['Category'] == 'Australia', 'Mean'] = np.mean(au)
de.loc[de['Category'] == 'Australia', 'Std Dev'] = np.std(au)
de.loc[de['Category'] == 'South America', 'Mean'] = np.mean(sa)
de.loc[de['Category'] == 'South America', 'Std Dev'] = np.std(sa)
de.loc[de['Category'] == 'Europe', 'Mean'] = np.mean(eu)
de.loc[de['Category'] == 'Europe', 'Std Dev'] = np.std(eu)
de.loc[de['Category'] == 'Antarctica', 'Mean'] = np.mean(an)
de.loc[de['Category'] == 'Antarctica', 'Std Dev'] = np.std(an)
de.loc[de['Category'] == 'Oceania', 'Mean'] = np.mean(oc)
de.loc[de['Category'] == 'Oceania', 'Std Dev'] = np.std(oc)
de.to_csv('/content/drive/My Drive/americas_vqa_continent.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# get the path/directory
file_path = ["/content/drive/MyDrive/Colab Notebooks/vqalabels/westasia_bicycle_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/westasia_car_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/westasia_truck_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/westasia_bus_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/westasia_boat_continent.txt"]
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/westasia_vqa_continent.txt"
# Ensure the folder exists
target_labels = ["africa", "north america", "europe", "south america", "asia", "australia", "oceania", "antarctica"]
count = 0
current_count = []
captions = []

for fp in file_path:
  with open(fp, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        captions.append(caption)

df = pd.DataFrame(captions, columns=['Captions'])
df = pd.DataFrame({
    'caption': captions
})

for label in target_labels:
    df[f'has_{label}'] = df['caption'].str.contains(label, case=False).astype(int)

af = []
na = []
eu = []
sa = []
asa = []
au = []
oc = []
an = []
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
    indices = np.random.choice(df.index, size=count, replace=True)
    sampled_df = df.loc[indices]
    print(f"sampled", sampled_df, file=output_file)
    column_sums = sampled_df.sum(axis=0)
    print(f"column sums", column_sums, file=output_file)
    column_probs = column_sums[1:9] / count
    print(f"column probs", column_probs, file=output_file)
    af.append(column_probs.iloc[0])
    na.append(column_probs.iloc[1])
    eu.append(column_probs.iloc[2])
    sa.append(column_probs.iloc[3])
    asa.append(column_probs.iloc[4])
    au.append(column_probs.iloc[5])
    oc.append(column_probs.iloc[6])
    an.append(column_probs.iloc[7])

data = {'Category': ['Africa', 'Asia', 'North America', 'Australia', 'South America', 'Europe', 'Antarctica', 'Oceania' ],
        'NumofImages': [count, count, count, count, count, count, count, count], 'Mean': [0, 0, 0, 0, 0, 0, 0, 0], 'Std Dev' : [0, 0, 0, 0, 0, 0, 0, 0] }
de = pd.DataFrame(data)
print(af)
de.loc[de['Category'] == 'Africa', 'Mean'] = np.mean(af)
de.loc[de['Category'] == 'Africa', 'Std Dev'] = np.std(af)
de.loc[de['Category'] == 'Asia', 'Mean'] = np.mean(asa)
de.loc[de['Category'] == 'Asia', 'Std Dev'] = np.std(asa)
de.loc[de['Category'] == 'North America', 'Mean'] = np.mean(na)
de.loc[de['Category'] == 'North America', 'Std Dev'] = np.std(na)
de.loc[de['Category'] == 'Australia', 'Mean'] = np.mean(au)
de.loc[de['Category'] == 'Australia', 'Std Dev'] = np.std(au)
de.loc[de['Category'] == 'South America', 'Mean'] = np.mean(sa)
de.loc[de['Category'] == 'South America', 'Std Dev'] = np.std(sa)
de.loc[de['Category'] == 'Europe', 'Mean'] = np.mean(eu)
de.loc[de['Category'] == 'Europe', 'Std Dev'] = np.std(eu)
de.loc[de['Category'] == 'Antarctica', 'Mean'] = np.mean(an)
de.loc[de['Category'] == 'Antarctica', 'Std Dev'] = np.std(an)
de.loc[de['Category'] == 'Oceania', 'Mean'] = np.mean(oc)
de.loc[de['Category'] == 'Oceania', 'Std Dev'] = np.std(oc)
de.to_csv('/content/drive/My Drive/westasia_vqa_continent.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# get the path/directory
file_path = ["/content/drive/MyDrive/Colab Notebooks/vqalabels/eastasia_bicycle_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/eastasia_car_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/eastasia_truck_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/eastasia_bus_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/eastasia_boat_continent.txt"]
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/eastasia_vqa_continent.txt"
# Ensure the folder exists
target_labels = ["africa", "north america", "europe", "south america", "asia", "australia", "oceania", "antarctica"]
count = 0
current_count = []
captions = []

for fp in file_path:
  with open(fp, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        captions.append(caption)

df = pd.DataFrame(captions, columns=['Captions'])
df = pd.DataFrame({
    'caption': captions
})

for label in target_labels:
    df[f'has_{label}'] = df['caption'].str.contains(label, case=False).astype(int)

af = []
na = []
eu = []
sa = []
asa = []
au = []
oc = []
an = []
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
    indices = np.random.choice(df.index, size=count, replace=True)
    sampled_df = df.loc[indices]
    print(f"sampled", sampled_df, file=output_file)
    column_sums = sampled_df.sum(axis=0)
    print(f"column sums", column_sums, file=output_file)
    column_probs = column_sums[1:9] / count
    print(f"column probs", column_probs, file=output_file)
    af.append(column_probs.iloc[0])
    na.append(column_probs.iloc[1])
    eu.append(column_probs.iloc[2])
    sa.append(column_probs.iloc[3])
    asa.append(column_probs.iloc[4])
    au.append(column_probs.iloc[5])
    oc.append(column_probs.iloc[6])
    an.append(column_probs.iloc[7])

data = {'Category': ['Africa', 'Asia', 'North America', 'Australia', 'South America', 'Europe', 'Antarctica', 'Oceania' ],
        'NumofImages': [count, count, count, count, count, count, count, count], 'Mean': [0, 0, 0, 0, 0, 0, 0, 0], 'Std Dev' : [0, 0, 0, 0, 0, 0, 0, 0] }
de = pd.DataFrame(data)
print(af)
de.loc[de['Category'] == 'Africa', 'Mean'] = np.mean(af)
de.loc[de['Category'] == 'Africa', 'Std Dev'] = np.std(af)
de.loc[de['Category'] == 'Asia', 'Mean'] = np.mean(asa)
de.loc[de['Category'] == 'Asia', 'Std Dev'] = np.std(asa)
de.loc[de['Category'] == 'North America', 'Mean'] = np.mean(na)
de.loc[de['Category'] == 'North America', 'Std Dev'] = np.std(na)
de.loc[de['Category'] == 'Australia', 'Mean'] = np.mean(au)
de.loc[de['Category'] == 'Australia', 'Std Dev'] = np.std(au)
de.loc[de['Category'] == 'South America', 'Mean'] = np.mean(sa)
de.loc[de['Category'] == 'South America', 'Std Dev'] = np.std(sa)
de.loc[de['Category'] == 'Europe', 'Mean'] = np.mean(eu)
de.loc[de['Category'] == 'Europe', 'Std Dev'] = np.std(eu)
de.loc[de['Category'] == 'Antarctica', 'Mean'] = np.mean(an)
de.loc[de['Category'] == 'Antarctica', 'Std Dev'] = np.std(an)
de.loc[de['Category'] == 'Oceania', 'Mean'] = np.mean(oc)
de.loc[de['Category'] == 'Oceania', 'Std Dev'] = np.std(oc)
de.to_csv('/content/drive/My Drive/eastasia_vqa_continent.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# get the path/directory
file_path = ["/content/drive/MyDrive/Colab Notebooks/vqalabels/europe_bicycle_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/europe_car_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/europe_truck_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/europe_bus_continent.txt",
             "/content/drive/My Drive/Colab Notebooks/vqalabels/europe_boat_continent.txt"]
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/europe_vqa_continent.txt"
# Ensure the folder exists
target_labels = ["africa", "north america", "europe", "south america", "asia", "australia", "oceania", "antarctica"]
count = 0
current_count = []
captions = []

for fp in file_path:
  with open(fp, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        captions.append(caption)

df = pd.DataFrame(captions, columns=['Captions'])
df = pd.DataFrame({
    'caption': captions
})

for label in target_labels:
    df[f'has_{label}'] = df['caption'].str.contains(label, case=False).astype(int)

af = []
na = []
eu = []
sa = []
asa = []
au = []
oc = []
an = []
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
    indices = np.random.choice(df.index, size=count, replace=True)
    sampled_df = df.loc[indices]
    print(f"sampled", sampled_df, file=output_file)
    column_sums = sampled_df.sum(axis=0)
    print(f"column sums", column_sums, file=output_file)
    column_probs = column_sums[1:9] / count
    print(f"column probs", column_probs, file=output_file)
    af.append(column_probs.iloc[0])
    na.append(column_probs.iloc[1])
    eu.append(column_probs.iloc[2])
    sa.append(column_probs.iloc[3])
    asa.append(column_probs.iloc[4])
    au.append(column_probs.iloc[5])
    oc.append(column_probs.iloc[6])
    an.append(column_probs.iloc[7])

data = {'Category': ['Africa', 'Asia', 'North America', 'Australia', 'South America', 'Europe', 'Antarctica', 'Oceania' ],
        'NumofImages': [count, count, count, count, count, count, count, count], 'Mean': [0, 0, 0, 0, 0, 0, 0, 0], 'Std Dev' : [0, 0, 0, 0, 0, 0, 0, 0] }
de = pd.DataFrame(data)
print(af)
de.loc[de['Category'] == 'Africa', 'Mean'] = np.mean(af)
de.loc[de['Category'] == 'Africa', 'Std Dev'] = np.std(af)
de.loc[de['Category'] == 'Asia', 'Mean'] = np.mean(asa)
de.loc[de['Category'] == 'Asia', 'Std Dev'] = np.std(asa)
de.loc[de['Category'] == 'North America', 'Mean'] = np.mean(na)
de.loc[de['Category'] == 'North America', 'Std Dev'] = np.std(na)
de.loc[de['Category'] == 'Australia', 'Mean'] = np.mean(au)
de.loc[de['Category'] == 'Australia', 'Std Dev'] = np.std(au)
de.loc[de['Category'] == 'South America', 'Mean'] = np.mean(sa)
de.loc[de['Category'] == 'South America', 'Std Dev'] = np.std(sa)
de.loc[de['Category'] == 'Europe', 'Mean'] = np.mean(eu)
de.loc[de['Category'] == 'Europe', 'Std Dev'] = np.std(eu)
de.loc[de['Category'] == 'Antarctica', 'Mean'] = np.mean(an)
de.loc[de['Category'] == 'Antarctica', 'Std Dev'] = np.std(an)
de.loc[de['Category'] == 'Oceania', 'Mean'] = np.mean(oc)
de.loc[de['Category'] == 'Oceania', 'Std Dev'] = np.std(oc)
de.to_csv('/content/drive/My Drive/europe_vqa_continent.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
