# %% [markdown]
# <a href="https://colab.research.google.com/github/smashiat/geography/blob/main/Captions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Create a DataFrame
data = {'Category': ['Bicycle', 'Car', 'Truck', 'Bus', 'Boat'],
        'NumofImages': [0, 0, 0, 0, 0], 'Mean': [0, 0, 0, 0, 0], 'Std Dev' : [0, 0, 0, 0, 0] }

df = pd.DataFrame(data)

# Save to CSV in your Drive
df.to_csv('/content/drive/My Drive/africa.csv', index=False)


drive.mount('/content/drive')
# get the path/directory
file_path = "/content/drive/MyDrive/Colab Notebooks/captions/africa_bicycle.txt"
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/africa_bicycle.txt"
# Ensure the folder exists
target_labels = ["bike", "bicycle", "motorcycle", "bikes", "bicycles", "motorcycles"]
count = 0
current_count = []

with open(file_path, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        if any(label in caption for label in target_labels):
          current_count.append(1)
        else:
          current_count.append(0)

# Update cells
df.loc[df['Category'] == 'Bicycle', 'NumofImages'] = count

label_counts = []
means = []
converged = False
iterations = 0
mean = 0
std_dev = 0
total = 0
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
      # Sample with replacement
      bootstrap_sample = random.choices(current_count, k=count)

      total = sum(bootstrap_sample)
      print(f"iterations", iterations, file=output_file)
      print(f"iterations", iterations)
      print(f"sample", bootstrap_sample, file=output_file)
      print(f"sample", bootstrap_sample)
      print(f"length", len(bootstrap_sample))
      print(f"total", total, file=output_file)
      print(f"total", total)
      new_prob = total / count
      print(f"count", count)
      print(f"new_prob", new_prob)
      label_counts.append(new_prob)
      print(f"label count", label_counts, file=output_file)
      mean = np.mean(label_counts)
      means.append(mean)
      print(f"means", means, file=output_file)
      print(f"means", means)
      std_dev = np.std(label_counts)
      print(f"std dev", std_dev, file=output_file)
      print(f"std dev", std_dev)
      iterations += 1


df.loc[df['Category'] == 'Bicycle', 'Mean'] = mean
df.loc[df['Category'] == 'Bicycle', 'Std Dev'] = std_dev
df.to_csv('/content/drive/My Drive/africa.csv', index=False)

# %%
import os
import random
import numpy as np
from PIL import Image
from pathlib import Path
from google.colab import drive
from collections import Counter

drive.mount('/content/drive')
# get the path/directory
file_path = "/content/drive/MyDrive/Colab Notebooks/captions/africa_car.txt"
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/africa_car.txt"

# Ensure the folder exists
target_labels = ["car", "cars", "jeep", "honda", "volkswagen", "hrx", "suv", "bmw", "lex", "toyota", "jaguar", "mazda", "limousine", "mercedes"]
count = 0
current_count = []

with open(file_path, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        if any(label in caption for label in target_labels):
          current_count.append(1)
        else:
          current_count.append(0)

df = pd.read_csv('/content/drive/My Drive/africa.csv')

df.loc[df['Category'] == 'Car', 'NumofImages'] = count

label_counts = []
means = []
converged = False
iterations = 0
mean = 0
std_dev = 0
total = 0
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
      # Sample with replacement
      bootstrap_sample = random.choices(current_count, k=count)

      total = sum(bootstrap_sample)
      print(f"iterations", iterations, file=output_file)
      print(f"iterations", iterations)
      print(f"sample", bootstrap_sample, file=output_file)
      print(f"sample", bootstrap_sample)
      print(f"length", len(bootstrap_sample))
      print(f"total", total, file=output_file)
      print(f"total", total)
      new_prob = total / count
      print(f"count", count)
      print(f"new_prob", new_prob)
      label_counts.append(new_prob)
      print(f"label count", label_counts, file=output_file)
      mean = np.mean(label_counts)
      means.append(mean)
      print(f"means", means, file=output_file)
      print(f"means", means)
      std_dev = np.std(label_counts)
      print(f"std dev", std_dev, file=output_file)
      print(f"std dev", std_dev)
      iterations += 1


df.loc[df['Category'] == 'Car', 'Mean'] = mean
df.loc[df['Category'] == 'Car', 'Std Dev'] = std_dev
df.to_csv('/content/drive/My Drive/africa.csv', index=False)

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter

drive.mount('/content/drive')
# get the path/directory
file_path = "/content/drive/MyDrive/Colab Notebooks/captions/africa_truck.txt"
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/africa_truck.txt"
# Ensure the folder exists
target_labels = ["truck", "trucks", "nissan", "ford"]
count = 0
current_count = []

with open(file_path, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        if any(label in caption for label in target_labels):
          current_count.append(1)
        else:
          current_count.append(0)

df = pd.read_csv('/content/drive/My Drive/africa.csv')

df.loc[df['Category'] == 'Truck', 'NumofImages'] = count

label_counts = []
means = []
converged = False
iterations = 0
mean = 0
std_dev = 0
total = 0
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
      # Sample with replacement
      bootstrap_sample = random.choices(current_count, k=count)

      total = sum(bootstrap_sample)
      print(f"iterations", iterations, file=output_file)
      print(f"iterations", iterations)
      print(f"sample", bootstrap_sample, file=output_file)
      print(f"sample", bootstrap_sample)
      print(f"length", len(bootstrap_sample))
      print(f"total", total, file=output_file)
      print(f"total", total)
      new_prob = total / count
      print(f"count", count)
      print(f"new_prob", new_prob)
      label_counts.append(new_prob)
      print(f"label count", label_counts, file=output_file)
      mean = np.mean(label_counts)
      means.append(mean)
      print(f"means", means, file=output_file)
      print(f"means", means)
      std_dev = np.std(label_counts)
      print(f"std dev", std_dev, file=output_file)
      print(f"std dev", std_dev)
      iterations += 1


df.loc[df['Category'] == 'Truck', 'Mean'] = mean
df.loc[df['Category'] == 'Truck', 'Std Dev'] = std_dev
df.to_csv('/content/drive/My Drive/africa.csv', index=False)

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter

drive.mount('/content/drive')
# get the path/directory
file_path = "/content/drive/MyDrive/Colab Notebooks/captions/africa_bus.txt"
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/africa_bus.txt"
# Ensure the folder exists
target_labels = ["bus", "buses", "van", "decker", "vans", "deckers"]
count = 0
current_count = []

with open(file_path, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        if any(label in caption for label in target_labels):
          current_count.append(1)
        else:
          current_count.append(0)

df = pd.read_csv('/content/drive/My Drive/africa.csv')

df.loc[df['Category'] == 'Bus', 'NumofImages'] = count

label_counts = []
means = []
converged = False
iterations = 0
mean = 0
std_dev = 0
total = 0
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
      # Sample with replacement
      bootstrap_sample = random.choices(current_count, k=count)

      total = sum(bootstrap_sample)
      print(f"iterations", iterations, file=output_file)
      print(f"iterations", iterations)
      print(f"sample", bootstrap_sample, file=output_file)
      print(f"sample", bootstrap_sample)
      print(f"length", len(bootstrap_sample))
      print(f"total", total, file=output_file)
      print(f"total", total)
      new_prob = total / count
      print(f"count", count)
      print(f"new_prob", new_prob)
      label_counts.append(new_prob)
      print(f"label count", label_counts, file=output_file)
      mean = np.mean(label_counts)
      means.append(mean)
      print(f"means", means, file=output_file)
      print(f"means", means)
      std_dev = np.std(label_counts)
      print(f"std dev", std_dev, file=output_file)
      print(f"std dev", std_dev)
      iterations += 1


df.loc[df['Category'] == 'Bus', 'Mean'] = mean
df.loc[df['Category'] == 'Bus', 'Std Dev'] = std_dev
df.to_csv('/content/drive/My Drive/africa.csv', index=False)

# %%
import os
import random
import numpy as np
from PIL import Image
from google.colab import drive
from collections import Counter

drive.mount('/content/drive')
# get the path/directory
file_path = "/content/drive/MyDrive/Colab Notebooks/captions/africa_boat.txt"
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/africa_boat.txt"
# Ensure the folder exists
target_labels = ["boat", "kayak", "kayaks", "ship", "ships", "boats", "canoe", "canoes", "sailboat", "sailboats"]
count = 0
current_count = []

with open(file_path, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        if any(label in caption for label in target_labels):
          current_count.append(1)
        else:
          current_count.append(0)

df = pd.read_csv('/content/drive/My Drive/africa.csv')

df.loc[df['Category'] == 'Boat', 'NumofImages'] = count

label_counts = []
means = []
converged = False
iterations = 0
mean = 0
std_dev = 0
total = 0
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
      # Sample with replacement
      bootstrap_sample = random.choices(current_count, k=count)

      total = sum(bootstrap_sample)
      print(f"iterations", iterations, file=output_file)
      print(f"iterations", iterations)
      print(f"sample", bootstrap_sample, file=output_file)
      print(f"sample", bootstrap_sample)
      print(f"length", len(bootstrap_sample))
      print(f"total", total, file=output_file)
      print(f"total", total)
      new_prob = total / count
      print(f"count", count)
      print(f"new_prob", new_prob)
      label_counts.append(new_prob)
      print(f"label count", label_counts, file=output_file)
      mean = np.mean(label_counts)
      means.append(mean)
      print(f"means", means, file=output_file)
      print(f"means", means)
      std_dev = np.std(label_counts)
      print(f"std dev", std_dev, file=output_file)
      print(f"std dev", std_dev)
      iterations += 1


df.loc[df['Category'] == 'Boat', 'Mean'] = mean
df.loc[df['Category'] == 'Boat', 'Std Dev'] = std_dev
df.to_csv('/content/drive/My Drive/africa.csv', index=False)

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter
drive.mount('/content/drive')

# Create a DataFrame
data = {'Category': ['Bicycle', 'Car', 'Truck', 'Bus', 'Boat'],
        'NumofImages': [0, 0, 0, 0, 0], 'Mean': [0, 0, 0, 0, 0], 'Std Dev' : [0, 0, 0, 0, 0] }

df = pd.DataFrame(data)

# Save to CSV in your Drive
df.to_csv('/content/drive/My Drive/europe.csv', index=False)

# get the path/directory
file_path = "/content/drive/MyDrive/Colab Notebooks/captions/europe_bicycle.txt"
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/europe_bicycle.txt"
# Ensure the folder exists
target_labels = ["bike", "bicycle", "motorcycle", "bikes", "bicycles", "motorcycles"]
count = 0
current_count = []

with open(file_path, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        if any(label in caption for label in target_labels):
          current_count.append(1)
        else:
          current_count.append(0)


df.loc[df['Category'] == 'Bicycle', 'NumofImages'] = count

label_counts = []
means = []
converged = False
iterations = 0
mean = 0
std_dev = 0
total = 0
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
      # Sample with replacement
      bootstrap_sample = random.choices(current_count, k=count)

      total = sum(bootstrap_sample)
      print(f"iterations", iterations, file=output_file)
      print(f"iterations", iterations)
      print(f"sample", bootstrap_sample, file=output_file)
      print(f"sample", bootstrap_sample)
      print(f"length", len(bootstrap_sample))
      print(f"total", total, file=output_file)
      print(f"total", total)
      new_prob = total / count
      print(f"count", count)
      print(f"new_prob", new_prob)
      label_counts.append(new_prob)
      print(f"label count", label_counts, file=output_file)
      mean = np.mean(label_counts)
      means.append(mean)
      print(f"means", means, file=output_file)
      print(f"means", means)
      std_dev = np.std(label_counts)
      print(f"std dev", std_dev, file=output_file)
      print(f"std dev", std_dev)
      iterations += 1


df.loc[df['Category'] == 'Bicycle', 'Mean'] = mean
df.loc[df['Category'] == 'Bicycle', 'Std Dev'] = std_dev
df.to_csv('/content/drive/My Drive/europe.csv', index=False)

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter

drive.mount('/content/drive')
# get the path/directory
file_path = "/content/drive/MyDrive/Colab Notebooks/captions/europe_car.txt"
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/europe_car.txt"
# Ensure the folder exists
target_labels = ["car", "cars", "jeep", "honda", "volkswagen", "hrx", "suv", "bmw", "lex", "toyota", "jaguar", "mazda", "limousine", "mercedes"]

df = pd.read_csv('/content/drive/My Drive/europe.csv')
count = 0
current_count = []

with open(file_path, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        if any(label in caption for label in target_labels):
          current_count.append(1)
        else:
          current_count.append(0)


df.loc[df['Category'] == 'Car', 'NumofImages'] = count

label_counts = []
means = []
converged = False
iterations = 0
mean = 0
std_dev = 0
total = 0
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
      # Sample with replacement
      bootstrap_sample = random.choices(current_count, k=count)

      total = sum(bootstrap_sample)
      print(f"iterations", iterations, file=output_file)
      print(f"iterations", iterations)
      print(f"sample", bootstrap_sample, file=output_file)
      print(f"sample", bootstrap_sample)
      print(f"length", len(bootstrap_sample))
      print(f"total", total, file=output_file)
      print(f"total", total)
      new_prob = total / count
      print(f"count", count)
      print(f"new_prob", new_prob)
      label_counts.append(new_prob)
      print(f"label count", label_counts, file=output_file)
      mean = np.mean(label_counts)
      means.append(mean)
      print(f"means", means, file=output_file)
      print(f"means", means)
      std_dev = np.std(label_counts)
      print(f"std dev", std_dev, file=output_file)
      print(f"std dev", std_dev)
      iterations += 1


df.loc[df['Category'] == 'Car', 'Mean'] = mean
df.loc[df['Category'] == 'Car', 'Std Dev'] = std_dev
df.to_csv('/content/drive/My Drive/europe.csv', index=False)

# %%
import os
import random
import numpy as np
from pathlib import Path
from google.colab import drive
from collections import Counter

drive.mount('/content/drive')
# get the path/directory
file_path = "/content/drive/MyDrive/Colab Notebooks/captions/europe_truck.txt"
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/europe_truck.txt"
# Ensure the folder exists
target_labels = ["truck", "trucks", "nissan", "ford"]
df = pd.read_csv('/content/drive/My Drive/europe.csv')

count = 0
current_count = []

with open(file_path, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        if any(label in caption for label in target_labels):
          current_count.append(1)
        else:
          current_count.append(0)


df.loc[df['Category'] == 'Truck', 'NumofImages'] = count

label_counts = []
means = []
converged = False
iterations = 0
mean = 0
std_dev = 0
total = 0
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
      # Sample with replacement
      bootstrap_sample = random.choices(current_count, k=count)

      total = sum(bootstrap_sample)
      print(f"iterations", iterations, file=output_file)
      print(f"iterations", iterations)
      print(f"sample", bootstrap_sample, file=output_file)
      print(f"sample", bootstrap_sample)
      print(f"length", len(bootstrap_sample))
      print(f"total", total, file=output_file)
      print(f"total", total)
      new_prob = total / count
      print(f"count", count)
      print(f"new_prob", new_prob)
      label_counts.append(new_prob)
      print(f"label count", label_counts, file=output_file)
      mean = np.mean(label_counts)
      means.append(mean)
      print(f"means", means, file=output_file)
      print(f"means", means)
      std_dev = np.std(label_counts)
      print(f"std dev", std_dev, file=output_file)
      print(f"std dev", std_dev)
      iterations += 1


df.loc[df['Category'] == 'Truck', 'Mean'] = mean
df.loc[df['Category'] == 'Truck', 'Std Dev'] = std_dev
df.to_csv('/content/drive/My Drive/europe.csv', index=False)

# %%
import os
import random
import numpy as np
from PIL import Image
from pathlib import Path
from google.colab import drive
from collections import Counter
from transformers import AutoProcessor, BlipForConditionalGeneration

drive.mount('/content/drive')
# get the path/directory
file_path = "/content/drive/MyDrive/Colab Notebooks/captions/europe_bus.txt"
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/europe_bus.txt"
# Ensure the folder exists
target_labels = ["bus", "buses", "van", "decker", "vans", "deckers"]
df = pd.read_csv('/content/drive/My Drive/europe.csv')

count = 0
current_count = []

with open(file_path, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        if any(label in caption for label in target_labels):
          current_count.append(1)
        else:
          current_count.append(0)


df.loc[df['Category'] == 'Bus', 'NumofImages'] = count

label_counts = []
means = []
converged = False
iterations = 0
mean = 0
std_dev = 0
total = 0
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
      # Sample with replacement
      bootstrap_sample = random.choices(current_count, k=count)

      total = sum(bootstrap_sample)
      print(f"iterations", iterations, file=output_file)
      print(f"iterations", iterations)
      print(f"sample", bootstrap_sample, file=output_file)
      print(f"sample", bootstrap_sample)
      print(f"length", len(bootstrap_sample))
      print(f"total", total, file=output_file)
      print(f"total", total)
      new_prob = total / count
      print(f"count", count)
      print(f"new_prob", new_prob)
      label_counts.append(new_prob)
      print(f"label count", label_counts, file=output_file)
      mean = np.mean(label_counts)
      means.append(mean)
      print(f"means", means, file=output_file)
      print(f"means", means)
      std_dev = np.std(label_counts)
      print(f"std dev", std_dev, file=output_file)
      print(f"std dev", std_dev)
      iterations += 1


df.loc[df['Category'] == 'Bus', 'Mean'] = mean
df.loc[df['Category'] == 'Bus', 'Std Dev'] = std_dev
df.to_csv('/content/drive/My Drive/europe.csv', index=False)

# %%
import os
import random
import numpy as np
from PIL import Image
from pathlib import Path
from google.colab import drive
from collections import Counter
from transformers import AutoProcessor, BlipForConditionalGeneration

drive.mount('/content/drive')
# get the path/directory
file_path = "/content/drive/MyDrive/Colab Notebooks/captions/europe_boat.txt"
output_path = "/content/drive/MyDrive/Colab Notebooks/stats/europe_boat.txt"
# Ensure the folder exists
target_labels = ["boat", "kayak", "kayaks", "ship", "ships", "boats", "canoe", "canoes", "sailboat", "sailboats"]
df = pd.read_csv('/content/drive/My Drive/europe.csv')

count = 0
current_count = []

with open(file_path, 'r') as file:
    lines = file.readlines()
    for i in range(0, len(lines), 2):
        filename = lines[i].strip()
        caption = lines[i+1].strip()
        count += 1
        if any(label in caption for label in target_labels):
          current_count.append(1)
        else:
          current_count.append(0)


df.loc[df['Category'] == 'Boat', 'NumofImages'] = count

label_counts = []
means = []
converged = False
iterations = 0
mean = 0
std_dev = 0
total = 0
with open(output_path, 'w') as output_file:
  for i in range(0, 500):
      # Sample with replacement
      bootstrap_sample = random.choices(current_count, k=count)

      total = sum(bootstrap_sample)
      print(f"iterations", iterations, file=output_file)
      print(f"iterations", iterations)
      print(f"sample", bootstrap_sample, file=output_file)
      print(f"sample", bootstrap_sample)
      print(f"length", len(bootstrap_sample))
      print(f"total", total, file=output_file)
      print(f"total", total)
      new_prob = total / count
      print(f"count", count)
      print(f"new_prob", new_prob)
      label_counts.append(new_prob)
      print(f"label count", label_counts, file=output_file)
      mean = np.mean(label_counts)
      means.append(mean)
      print(f"means", means, file=output_file)
      print(f"means", means)
      std_dev = np.std(label_counts)
      print(f"std dev", std_dev, file=output_file)
      print(f"std dev", std_dev)
      iterations += 1


df.loc[df['Category'] == 'Boat', 'Mean'] = mean
df.loc[df['Category'] == 'Boat', 'Std Dev'] = std_dev
df.to_csv('/content/drive/My Drive/europe.csv', index=False)
